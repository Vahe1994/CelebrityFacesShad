# %%
import face_recognition
import scipy as sp
import scipy.misc
import matplotlib.pyplot as plt
import numpy as np
from imageio import imread
# %matplotlib inline

# %%
image = face_recognition.load_image_file("Jessica-Alba-Hot-photoshoot-2-834x1024.jpg")
face_locations = face_recognition.face_locations(image)

# %%
plt.figure(figsize=(10,8))
plt.subplot(1,2,1)
# im = imread('BBBC018_v1_images-fixed/train/00735-actin.DIB.bmp')
plt.imshow(image)

# %%
plt.figure(figsize=(10,8))
plt.subplot(1,2,1)
# im = imread('BBBC018_v1_images-fixed/train/00735-actin.DIB.bmp')
plt.imshow(image[list(face_locations[0])[0]:list(face_locations[0])[2],list(face_locations[0])[3]:list(face_locations[0])[1]])

# %%
image = face_recognition.load_image_file("Penelopa.jpg")
face_locations = face_recognition.face_locations(image)

# %%
plt.figure(figsize=(10,8))
plt.subplot(1,2,1)
# im = imread('BBBC018_v1_images-fixed/train/00735-actin.DIB.bmp')
plt.imshow(image)

# %%
plt.figure(figsize=(10,8))
plt.subplot(1,2,1)
# im = imread('BBBC018_v1_images-fixed/train/00735-actin.DIB.bmp')
plt.imshow(image[list(face_locations[0])[0]:list(face_locations[0])[2],list(face_locations[0])[3]:list(face_locations[0])[1]])

# %%
def get_face(img=None,url=None):
    face_locations=None
    if img is None:
        image = face_recognition.load_image_file("Jessica-Alba-Hot-photoshoot-2-834x1024.jpg")
        face_locations = face_recognition.face_locations(image)
    else:
        face_locations = face_recognition.face_locations(img)
    img =img[list(face_locations[0])[0]:list(face_locations[0])[2],list(face_locations[0])[3]:list(face_locations[0])[1]]
    return img

# %%
plt.figure(figsize=(10,8))
plt.subplot(1,2,1)
# im = imread('BBBC018_v1_images-fixed/train/00735-actin.DIB.bmp')
plt.imshow(get_face(image))

# %% [markdown]
# ### You need to add folder to your Pythonpath

# %%
import CilibrityFaceShad.src.Facecrop as Facecrop

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
croped_img = Facecrop.get_face(img = None,url = 'z.jpg')

# %%
plt.figure(figsize=(10,8))
plt.subplot(1,2,1)
# im = imread('BBBC018_v1_images-fixed/train/00735-actin.DIB.bmp')
plt.imshow(croped_img)
